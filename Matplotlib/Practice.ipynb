# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 📊 3D Plotting Practice Questions in Matplotlib
#
# ## ✅ 1. 3D Surface Plot Practice
#
# ### Q1. Surface Plot of `z = cos(x² + y²)`
# - Let `x` and `y` range from -4 to 4.
# - Use a `coolwarm` colormap.
# - Add a color bar.
#
# ---
#
# ### Q2. Saddle Surface Plot of `z = x² - y²`
# - Set `x` and `y` in range -5 to 5.
# - Apply a colormap of your choice.
# - Label all three axes.
#
# ---
#
# ### Q3. Animated Surface Plot
# - Animate the surface `z = sin(sqrt(x² + y² - t))` for values of `t` from 0 to 5.
# - Use a loop and pause briefly between frames using `plt.pause()`.
#
# ---
#
# ## ✅ 2. 3D Line Plot Practice
#
# ### Q4. Helix Plot
# - Use the parametric equations:
#   - `x = cos(t)`
#   - `y = sin(t)`
#   - `z = t`
# - Let `t` range from 0 to 4π.
# - Add markers and make the line color red.
#
# ---
#
# ### Q5. Outward Spiral in 3D
# - Use parametric equations:
#   - `x = t * cos(t)`
#   - `y = t * sin(t)`
#   - `z = t`
# - Plot using dashed line style (`linestyle="--"`).
# - Add title: **"3D Spiral Curve"**
#
# ---
#
# ## ✅ 3. 3D Scatter Plot Practice
#
# ### Q6. Random 3D Scatter Points
# - Generate 100 random values each for `x`, `y`, and `z` in range 0 to 10.
# - Color the points based on `z` values using a colormap.
# - Use varying marker sizes based on `x` values.
#
# ---
#
# ### Q7. Categorized 3D Scatter Clusters
# - Create 3 clusters of 3D points (e.g., using normal distributions).
# - Each cluster should have a different color and label.
# - Show the legend using `ax.legend()`.
#
# ---
#
# ## ✅ Bonus: Combine Surface + Scatter
#
# ### Q8. Mixed Plot: Surface + Scatter
# - Plot surface `z = sin(x) * cos(y)`
# - Overlay red 3D scatter points on top where `z > 0.5`.

# %% [markdown]
# # Answers:
# ## Answer 1

# %%
x = np.linspace(-4,4,100)
y = np.linspace(-4,4,100)
x,y = np.meshgrid(x,y)
z = np.cos(x**2+y**2)

fig = plt.figure()
ax = plt.subplot(projection="3d")
var = ax.plot_surface(x,y,z,cmap="coolwarm")
fig.colorbar(var)
plt.show()

# %% [markdown]
# ## Answer 2

# %%
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100)
x,y = np.meshgrid(x,y)
z = x**2-y**2

fig = plt.figure()
ax = plt.subplot(projection="3d")
var = ax.plot_surface(x,y,z,cmap="bone")
fig.colorbar(var)
ax.set_title("Surface Plot of z = x² - y²")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z = x² - y²")
plt.show()

# %%
from matplotlib import colormaps

# %% [markdown]
# ## Answer 3:

# %%
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100)
x,y = np.meshgrid(x,y)
for t in range(6):
    z = np.sin(np.sqrt(np.maximum(0, x**2 + y**2 - t)))
    fig = plt.figure()
    ax = plt.subplot(projection="3d")
    var = ax.plot_surface(x,y,z,cmap="jet")
    fig.colorbar(var)
    ax.set_title("Surface Plot of z = sin(sqrt(x² + y² - t))")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z = sin(sqrt(x² + y² - t))")
    plt.pause(2)
    plt.show()

# %% [markdown]
# ## Answer 4

# %%
t = np.linspace(0,4*np.pi,100)
x = np.cos(t)
y = np.sin(t)
z = t

fig = plt.figure()
ax = plt.subplot(projection = "3d")
ax.plot(x,y,z,marker=".",color="red")
ax.set_title("Line plot")
ax.set_xlabel("cos(t)")
ax.set_ylabel("sin(t)")
ax.set_zlabel("t")
plt.show()

# %% [markdown]
# ## Answer 5

# %%
t = np.linspace(0,4*np.pi,100)
x = t * np.cos(t)
y = t * np.sin(t)
z = t

fig = plt.figure()
ax = plt.subplot(projection = "3d")
ax.plot(x,y,z,linestyle="--",color="green")
ax.set_title("3D Spiral Curve")
ax.set_xlabel("t x cos(t)")
ax.set_ylabel("t x sin(t)")
ax.set_zlabel("t")
plt.show()

# %% [markdown]
# ## Answer 6

# %%
np.random.seed(24)
x = np.random.randint(0,10,100)
y = np.random.randint(0,10,100)
z = np.random.randint(0,10,100)

fig = plt.figure()
ax = plt.subplot(projection="3d")
var = ax.scatter(x,y,z,c=z,s=x*10,marker="o",cmap="plasma")
ax.set_title("")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
fig.colorbar(var)
plt.show()

# %% [markdown]
# ## Answer 7

# %%
# For consistent random values
np.random.seed(42)

# Generate 3 clusters (30 points each)
x1 = np.random.normal(2, 0.5, 30)
y1 = np.random.normal(2, 0.5, 30)
z1 = np.random.normal(2, 0.5, 30)

x2 = np.random.normal(7, 0.5, 30)
y2 = np.random.normal(7, 0.5, 30)
z2 = np.random.normal(7, 0.5, 30)

x3 = np.random.normal(5, 0.5, 30)
y3 = np.random.normal(1, 0.5, 30)
z3 = np.random.normal(9, 0.5, 30)

# Plotting
fig = plt.figure()
ax = fig.add_subplot(projection="3d")

# Scatter each cluster with different color and label
ax.scatter(x1, y1, z1, c='blue', label='Cluster A', alpha=0.7)
ax.scatter(x2, y2, z2, c='red', label='Cluster B', alpha=0.7)
ax.scatter(x3, y3, z3, c='green', label='Cluster C', alpha=0.7)

# Labels and legend
ax.set_title("3D Categorized Scatter Clusters")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.legend()

plt.show()

# %% [markdown]
# ## Answer 8

# %%
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100)
x,y = np.meshgrid(x,y)
z = np.sin(x) * np.cos(y)

fig = plt.figure()
ax = fig.add_subplot(projection="3d")
var = ax.plot_surface(x,y,z,cmap="Blues")
mask = z > 0.5
xx = x[mask]
yy = y[mask]
zz = z[mask]

ax.scatter(xx,yy,zz,c="red",s=1)
ax.set_title("z = sin(x) * cos(y)")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("sin(x) * cos(y)")
fig.colorbar(var)
plt.show()
