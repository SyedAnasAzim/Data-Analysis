# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv("02/iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ## colorued in scatter plot
# the c parameter is used to specify the color(s) of the points in the scatter plot.

# %%
iris["Species"] = iris["Species"].replace({"Iris-setosa":0,"Iris-versicolor":1,"Iris-virginica":2})
iris
# Out:
# C:\Users\AK\AppData\Local\Temp\ipykernel_12296\2368914512.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris["Species"] = iris["Species"].replace({"Iris-setosa":0,"Iris-versicolor":1,"Iris-virginica":2})
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# ...

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"])

# %% [markdown]
# now, we get color to change the colors we can use ***camp*** parameter

# %% [markdown]
# #### cmap parameter
# **It's used when the c parameter is an array of numerical values — it maps those values to a range of colors from the chosen colormap.**

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"],cmap="summer")
plt.ylabel("PetalLengthCm")
plt.xlabel("SepalLengthCm")
# Out:
# Text(0.5, 0, 'SepalLengthCm')

# %% [markdown]
# | Name        | Description                   |
# | ----------- | ----------------------------- |
# | `'viridis'` | Default, smooth green to blue |
# | `'plasma'`  | Purple → orange               |
# | `'inferno'` | Black → red → yellow          |
# | `'magma'`   | Black → purple → white        |
# | `'cool'`    | Cyan → magenta                |
# | `'hot'`     | Black → red → yellow → white  |
# | `'Greys'`   | Shades of grey                |
# | `'rainbow'` | Full rainbow colors           |

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"],cmap="winter")
plt.ylabel("PetalLengthCm")
plt.xlabel("SepalLengthCm")
# Out:
# Text(0.5, 0, 'SepalLengthCm')

# %% [markdown]
# #### colorbar()
# The colorbar() function adds a color scale (legend) to your plot, which shows how numeric values are mapped to colors when using colormaps (cmap) — especially useful with scatter(), imshow(), contourf(), etc.

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"],cmap="jet")
plt.ylabel("PetalLengthCm")
plt.xlabel("SepalLengthCm")
plt.colorbar()

# %% [markdown]
# **Here, color bar helps us in kind of labelling by showing which color represents which species of iris.**

# %% [markdown]
# #### alpha Parameter in Matplotlib
# The alpha parameter controls the transparency (opacity) of plot elements.
#
# **Value Range:**
# * alpha = 0 → completely transparent
# * alpha = 1 → fully opaque
# * Any float between 0 and 1 adjusts the transparency accordingly.
#
# **Why use alpha?**
# * Useful for overlaying plots to see overlaps.
# * Helps reduce visual clutter(*Too much information shown at once, making the plot hard to read or understand*) in dense plots.

# %%
from matplotlib import colormaps
list(colormaps)
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
# ...

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"],cmap="Set1_r",alpha=0.5)
plt.ylabel("PetalLengthCm")
plt.xlabel("SepalLengthCm")
plt.colorbar()

# %% [markdown]
# ### Instead of assigning numerical values we can assign directly colors to species

# %%
iris1 = pd.read_csv("02/iris.csv")
iris1["Species"] = iris1["Species"].replace({
    "Iris-setosa":"cyan",
    "Iris-versicolor":"coral",
    "Iris-virginica":"yellow"
})
iris1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0      1            5.1           3.5            1.4           0.2    cyan
# 1      2            4.9           3.0            1.4           0.2    cyan
# 2      3            4.7           3.2            1.3           0.2    cyan
# 3      4            4.6           3.1            1.5           0.2    cyan
# 4      5            5.0           3.6            1.4           0.2    cyan
# ..   ...            ...           ...            ...           ...     ...
# 145  146            6.7           3.0            5.2           2.3  yellow
# 146  147            6.3           2.5            5.0           1.9  yellow
# 147  148            6.5           3.0            5.2           2.0  yellow
# 148  149            6.2           3.4            5.4           2.3  yellow
# 149  150            5.9           3.0            5.1           1.8  yellow
#
# [150 rows x 6 columns]

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"])
plt.colorbar()

# %% [markdown]
# ***The cmap (colormap) parameter is meant for numerical data. It converts a range of numbers into colors based on the colormap you choose.So, there is no need here.***

# %% [markdown]
# ## Plot Size
# In matplotlib, you can set the plot size using the figsize parameter inside plt.figure() or plt.subplots().
#
# **Notes:**
# * Units are in inches.
# * Default is usually around (6.4, 4.8).
# * figsize must be passed before plotting; if you try changing it after plt.plot(), it won't work.
# * figzie=(width,height)
# * applicable on any graph

# %%
plt.figure(figsize=(15,7))

plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"],cmap="jet")
plt.ylabel("PetalLengthCm")
plt.xlabel("SepalLengthCm")
plt.colorbar()

# %%
plt.figure(figsize=(1,1))

plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"],cmap="jet")
plt.ylabel("PetalLengthCm")
plt.xlabel("SepalLengthCm")
plt.colorbar()

# %% [markdown]
# ## Annotations

# %%
batters = pd.read_csv("02/batter.csv")
sample_df = batters.head(100).sample(25,random_state=5)
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %% [markdown]
# **random_state=42** or **np.random.seed(42)** sets the random number generator to a fixed starting point for reproducibility.
# - You can use any integer; 42 is just a common example (often used humorously).
# - Using the same seed ensures you get the same "random" results every time.

# %% [markdown]
# ### using text

# %%
x = [1,2,3,4]
y = [1,2,3,4]
plt.scatter(x,y)
plt.text(x[0],y[0],"1st point",fontdict={"color":"skyblue","size":12,"weight":"bold"})
plt.text(x[1],y[1],"2nd point")
plt.text(x[2],y[2],"3rd point")
plt.text(x[3],y[3],"4th point")
# Out:
# Text(4, 4, '4th point')

# %%
plt.scatter(sample_df["avg"],sample_df["strike_rate"])
for i in sample_df.index:
    plt.text(sample_df["avg"][i]+0.1,sample_df["strike_rate"][i]+0.1,sample_df["batter"][i])
plt.show()

# %% [markdown]
# ### Using annotate()

# %%
plt.figure(figsize=(18,10))
plt.scatter(sample_df["avg"],sample_df["strike_rate"],s=sample_df["runs"])
for i in sample_df.index:
    plt.annotate(
        sample_df["batter"].loc[i],
        xy=(sample_df["avg"].loc[i],sample_df["strike_rate"].loc[i]),
        xytext=(sample_df["avg"].loc[i]+0.1,sample_df["strike_rate"].loc[i]+0.1),
        fontsize=12,color="coral",
        weight="bold"
)
plt.show()

# %% [markdown]
# ## Horizontal and Vertical lines

# %%
plt.figure(figsize=(18,10))
plt.scatter(sample_df["avg"],sample_df["strike_rate"],s=sample_df["runs"])
for i in sample_df.index:
    plt.annotate(
        sample_df["batter"].loc[i],
        xy=(sample_df["avg"].loc[i],sample_df["strike_rate"].loc[i]),
        xytext=(sample_df["avg"].loc[i]+0.1,sample_df["strike_rate"].loc[i]+0.1),
        fontsize=12,color="coral",
        weight="bold"
)
plt.axhline(130,color="red") #hozontal line or on y-axis or || to x-axis
plt.axvline(30,color="red") #vertical line or on x-axis or || to y-axis
plt.show()

# %% [markdown]
# **We can also plot multiple lines**

# %%
plt.figure(figsize=(18,10))
plt.scatter(sample_df["avg"],sample_df["strike_rate"],s=sample_df["runs"])
for i in sample_df.index:
    plt.annotate(
        sample_df["batter"].loc[i],
        xy=(sample_df["avg"].loc[i],sample_df["strike_rate"].loc[i]),
        xytext=(sample_df["avg"].loc[i]+0.1,sample_df["strike_rate"].loc[i]+0.1),
        fontsize=12,color="coral",
        weight="bold"
)
plt.axhline(130,color="red") #hozontal line or on y-axis or || to x-axis
plt.axvline(30,color="red") #vertical line or on x-axis or || to y-axis
plt.axhline(140,color="green")
plt.show()

# %% [markdown]
# ## Subplots
# The plt.subplot() function is used to create multiple plots (subplots) in the same figure window.
#
# **Use:**
# * When analyzing multiple columns, it would be helpful.

# %% [markdown]
# ***First, before this, we will learn another way to show plots.***

# %%
fig,ax = plt.subplots()
ax.scatter(batters["avg"],batters["strike_rate"])

# %%
fig,ax = plt.subplots()
ax.plot(batters["avg"],batters["strike_rate"])

# %%
fig,ax = plt.subplots(figsize=(15,10))
ax.scatter(batters["avg"],batters["strike_rate"],color="red",s=101,marker="+")
ax.set_title("avg vs strike rate")
ax.set_xlabel("Average")
ax.set_ylabel("Strike Rate")
fig.show()
# Out:
# C:\Users\AK\AppData\Local\Temp\ipykernel_12296\1240794970.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# #### now, back to subplots
# **plt.subplots(row,col)**

# %%
fig,ax = plt.subplots(2,1)
ax # -> array of axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
# 2D array
fig,ax = plt.subplots(2,2)
ax[0][1] # -> array of axes
# Out:
# <Axes: >

# %% [markdown]
# **2D array of axes could accessed by ax[0,1],ax[2,1] etc.**
#
# ***ax[0][1] still works, but it's slightly less efficient.***

# %%
fig,ax = plt.subplots(nrows=2,ncols=1)
ax[0].scatter(batters["runs"],batters["avg"])
ax[0].set_title("Runs vs Average")
ax[0].set_xlabel("Runs")
ax[0].set_ylabel("Avergae")

ax[1].scatter(batters["avg"],batters["strike_rate"])
ax[1].set_title("Average vs Strike Rate")
ax[1].set_xlabel("Average")
ax[1].set_ylabel("Strike Rate")

fig.tight_layout()# to avoid overlapping
fig.show()
# Out:
# C:\Users\AK\AppData\Local\Temp\ipykernel_12296\814430724.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# **When you create multiple subplots, things like axis labels and titles may overlap or get cut off.
# tight_layout() fixes this automatically.**

# %%
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(10,6))
ax[0, 0].scatter(batters["runs"],batters["avg"],c="gold")
ax[0, 0].set_title("Runs vs Average")
ax[0, 0].set_xlabel("Runs")
ax[0, 0].set_ylabel("Avergae")

ax[0, 1].scatter(batters["avg"],batters["strike_rate"],c="green")
ax[0, 1].set_title("Average vs Strike Rate")
ax[0, 1].set_xlabel("Average")
ax[0, 1].set_ylabel("Strike Rate")

ax[1, 0].hist(batters["avg"],color="red")
ax[1, 0].set_title("Average Histogram")
ax[1, 0].set_xlabel("Average")
ax[1, 0].set_ylabel("Number of Batters")

ax[1, 1].hist(batters["strike_rate"])
ax[1, 1].set_title("Strike Rate Histogram")
ax[1, 1].set_xlabel("Strike Rate")
ax[1, 1].set_ylabel("Number of Batters")

fig.tight_layout()# to avoid overlapping
fig.show()
# Out:
# C:\Users\AK\AppData\Local\Temp\ipykernel_12296\2565353152.py:23: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# **There is a 3rd way to show plots**

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax1.scatter(batters["runs"],batters["avg"])

ax2 = fig.add_subplot(2,2,2)# (212) both with or without are ok
ax2.scatter(batters["strike_rate"],batters["avg"])

ax3 = fig.add_subplot(2,2,3)
ax3.hist(batters["avg"])

ax3 = fig.add_subplot(224)
ax3.hist(batters["strike_rate"])

fig.tight_layout()
fig.show()
# Out:
# C:\Users\AK\AppData\Local\Temp\ipykernel_12296\324399228.py:15: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Another way

# %% [markdown]
# **Here, we use subplot not subplots**

# %%
plt.subplot(411)
plt.scatter(batters["runs"],batters["avg"])

plt.subplot(412)
plt.scatter(batters["strike_rate"],batters["avg"])

plt.subplot(4,1,3)
plt.hist(batters["avg"])

plt.subplot(414)
plt.hist(batters["strike_rate"])

plt.tight_layout()
plt.show()

# %% [markdown]
# **use *plt.show()* instead of *fig.show()***

# %% [markdown]
# ## 3d Scatter Plot

# %%
fig = plt.figure()
ax = plt.subplot(projection = "3d")
ax.scatter3D(batters["runs"],batters["avg"],batters["strike_rate"])
ax.set_title("IPL Batsmen Analysis")
ax.set_xlabel("Runs")
ax.set_ylabel("Average")
ax.set_zlabel("Strike Rate")
plt.show()

# %% [markdown]
# ## 3D Line Plot

# %%
x = [0,5,14,15]
y = [1,7,21,2]
z = [2,3,18,34]

fig = plt.figure()
ax = plt.subplot(projection = "3d")
ax.plot3D(x,y,z)
ax.scatter(x,y,z,s=[100,100,100,100],color="red")
plt.show()

# %% [markdown]
# ## 3D Surface Plots

# %% [markdown]
# A 3D surface plot is used to visualize three-dimensional data. It shows a surface that connects a set of data points in 3D space using color and elevation to represent a fourth dimension (z-values based on x and y).

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx,yy = np.meshgrid(x,y)
z = xx**2 + yy**2

plt.figure()
ax = plt.subplot(projection="3d")
ax.plot_surface(xx,yy,z)

# %% [markdown]
# #### np.meshgrid
# numpy.meshgrid is a function that takes two 1D arrays representing x and y coordinates and returns coordinate matrices from them. These coordinate matrices are used for evaluating functions over a grid—like in 3D plotting (e.g., surface plots).

# %%
x = np.array([1, 2, 3])  # X-coordinates
y = np.array([10, 20])   # Y-coordinates

X, Y = np.meshgrid(x, y)

print("X:\n", X)
print("Y:\n", Y)
# Out:
# X:
#  [[1 2 3]
#  [1 2 3]]
# Y:
#  [[10 10 10]
#  [20 20 20]]

# %% [markdown]
# **What does it do?**
# * It expands your 1D x and y arrays into 2D grids.
# * Now you can calculate values (like z = f(x, y)) at each combination of x and y.
#
# (x=1, y=10), (x=2, y=10), (x=3, y=10)
# (x=1, y=20), (x=2, y=20), (x=3, y=20)

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx,yy = np.meshgrid(x,y)
z = xx**2 + yy**2

plt.figure()
ax = plt.subplot(projection="3d")
ax.plot_surface(xx,yy,z,cmap="viridis")

# %% [markdown]
# **for color bar first we have to store it in a variable then give it as input to fig.colorbar(var)**

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx,yy = np.meshgrid(x,y)
z = xx**2 + yy**2

fig = plt.figure()
ax = plt.subplot(projection="3d")
p = ax.plot_surface(xx,yy,z,cmap="cool")
fig.colorbar(p)

# %% [markdown]
# ***Here, we can see that cyan represents low value of z and pink represents high value.***

# %%
z = np.sin(xx) + np.cos(yy)

fig = plt.figure()
ax = fig.add_subplot(projection="3d")
var = ax.plot_surface(xx,yy,z,cmap="inferno")
fig.colorbar(var)

# %% [markdown]
# ## Contour Plot
# ### What is a Contour Plot?
# **A contour plot is a 2D plot used to represent a 3D surface. It shows lines of constant value (like height, temperature, pressure, etc.) on a flat surface.**
#
# **Think of it like a topographic map — the kind that shows mountains and valleys using curved lines.**
# ### Real-Life Analogy
# **Imagine a mountain:**
# * From the side, you see the height (3D surface).
# * From the top (bird’s eye view), you only see lines connecting points at the same height.
# Those lines are contour lines.
# ### Why Use Contour Plots?
# Contour plots are useful when:
# * You want to see the shape of a surface without plotting it in 3D.
# * You're working with heatmaps, elevation maps, or anything with 3 variables:
#     - ***x, y (horizontal position)***
#     - ***z (value/height at each point)***
# ### How to Read a Contour Plot
# * Each line represents a constant z-value (e.g. temperature = 50°C).
# * If lines are close together, the surface is steep.
# * If lines are far apart, the surface is flat.
# * The shape of lines tells you how the surface behaves.

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx,yy = np.meshgrid(x,y)
z = xx**2 + yy**2

fig = plt.figure()
ax = plt.subplot(projection="3d")
p = ax.plot_surface(xx,yy,z,cmap="viridis")
fig.colorbar(p)

# %% [markdown]
# **Here, this 3D graph is converted into 2D and we are watching it from top.**

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx,yy = np.meshgrid(x,y)
z = xx**2 + yy**2

fig = plt.figure()
ax = plt.subplot()
p = ax.contour(xx,yy,z,cmap="viridis")
fig.colorbar(p)

# %% [markdown]
# * Using levels parameter to increase the lines.
# * The levels parameter controls how many contour lines or filled color bands you see in your plot.

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx,yy = np.meshgrid(x,y)
z = xx**2 + yy**2

fig = plt.figure()
ax = plt.subplot()
p = ax.contour(xx,yy,z,cmap="viridis",levels=20)
fig.colorbar(p)

# %% [markdown]
# **fig.colorbar(p) at the will help us understand depth that which is lower and above.**

# %% [markdown]
# ### What is a Filled Contour Plot?
# * A filled contour plot is like a contour plot — but instead of just drawing lines, it fills the spaces between those lines with color.
# * It’s a 2D way to visualize a 3D surface by using color intensity to show how high or low the values are.

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx,yy = np.meshgrid(x,y)
z = xx**2 + yy**2

fig = plt.figure()
ax = plt.subplot()
p = ax.contourf(xx,yy,z,cmap="viridis")
fig.colorbar(p)

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx,yy = np.meshgrid(x,y)
z = xx**2 + yy**2

fig = plt.figure()
ax = plt.subplot()
p = ax.contourf(xx,yy,z,cmap="viridis",levels=20)
fig.colorbar(p)

# %%
z = np.sin(xx) + np.cos(yy)

fig = plt.figure()
ax = fig.add_subplot()
var = ax.contourf(xx,yy,z,cmap="inferno")
fig.colorbar(var)

# %% [markdown]
# ## Heatmap

# %%
deliveries = pd.read_csv("02/IPL_Ball_by_Ball_2008_2022.csv")
deliveries.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
temp_df = deliveries[(deliveries["ballnumber"].isin([1,2,3,4,5,6])) & (deliveries["batsman_run"]==6)]
temp_df.head()
# Out:
#           ID  innings  overs  ballnumber       batter             bowler  \
# 16   1312200        1      2           5  YBK Jaiswal     Mohammed Shami
# 22   1312200        1      3           5  YBK Jaiswal         Yash Dayal
# 103  1312200        1     17           2     TA Boult      R Sai Kishore
# 107  1312200        1     17           6     OC McCoy      R Sai Kishore
# 142  1312200        2      3           5      MS Wade  M Prasidh Krishna
#
#       non-striker extra_type  batsman_run  extras_run  total_run  \
# 16     JC Buttler        NaN            6           0          6
# 22     JC Buttler        NaN            6           0          6
# 103       R Parag        NaN            6           0          6
# 107       R Parag        NaN            6           0          6
# 142  Shubman Gill        NaN            6           0          6
#
#      non_boundary  isWicketDelivery player_out kind fielders_involved  \
# ...

# %%
# temp_df.groupby(["overs",'ballnumber'])["total_run"].count().unstack()

# %%
grid = pd.pivot_table(temp_df,index="overs",columns="ballnumber",values="total_run",aggfunc="count")
grid
# Out:
# ballnumber    1    2    3    4    5    6
# overs
# 0             9   17   31   39   33   27
# 1            31   40   49   56   58   54
# 2            75   62   70   72   58   76
# 3            60   74   74  103   74   71
# 4            71   76  112   80   81   72
# 5            77  102   63   86   78   80
# 6            34   56   49   59   64   38
# 7            59   62   73   70   69   56
# 8            86   83   79   81   73   52
# 9            54   62   86   61   74   67
# 10           82   92   83   69   72   70
# 11           91   72   87   79   87   70
# 12           87  109   79  100  100   84
# 13          101  101   99   97   90   88
# 14           90  124  103  100   86  106
# 15          102  120  129  121  113   96
# 16          107  115  111  100  120  101
# 17          126  142  137  151  117  129
# 18          118  114  151  132  138  128
# 19          136  120  151  151  116  148

# %%
plt.figure(figsize=(20,10))
plt.imshow(grid)
plt.xticks(np.arange(6),np.arange(1,7))
plt.yticks(np.arange(20),np.arange(1,21))
plt.colorbar()

# %% [markdown]
# ## Pandas plot()

# %% [markdown]
# ### 1. Matplotlib
# * Low-level plotting library (more control).
# * You have to build everything manually: figure, axes, labels, etc.
# * Very flexible and customizable.
# * Used as the base for other libraries (Seaborn, Pandas, etc.)
#
# ### 2. Pandas .plot()
# * High-level plotting (easy and quick).
# * Built on top of Matplotlib.
# * Automatically understands DataFrames and Series.
# * Useful when working with tabular data.
#
# | Feature          | **Matplotlib**        | **Pandas `.plot()`**        |
# | ---------------- | --------------------- | --------------------------- |
# | Level            | Low-level             | High-level                  |
# | Flexibility      | Very high             | Medium                      |
# | Ease of use      | More complex          | Very simple                 |
# | Works best with  | Any kind of data      | DataFrames / Series         |
# | Customization    | Full control          | Limited, but can use kwargs |
# | Speed of writing | Slower                | Faster                      |
# | Base library for | Pandas, Seaborn, etc. | Depends on Matplotlib       |

# %% [markdown]
# ### on a series

# %%
ser = pd.Series([1,2,3,4,5,6,7])
ser.plot() #kind = "line" --> default
# here, x-axis is index and y-axis is our values
# Out:
# <Axes: >

# %%
ser = pd.Series([1,2,3,4,5,6,7])
ser.hist()
# Out:
# <Axes: >

# %% [markdown]
# ### can be used on a dataframe as well

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Scatter Plot
# * **labels**
# * **marker**
# * **figsize**
# * **color**
# * **cmap**
# * **s**

# %%
tips.plot(
    kind="scatter",
    x="total_bill",
    y="tip",title="Cost Analysis",
    color="coral",
    marker="*",
    figsize=(10,6),
    s="size",
)
# Out:
# <Axes: title={'center': 'Cost Analysis'}, xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# **size is too small so we give there, we do this**

# %%
tips.plot(
    kind="scatter",
    x="total_bill",
    y="tip",title="Cost Analysis",
    color="coral",
    marker="*",
    figsize=(10,6),
    s=tips["size"]*20
)
# Out:
# <Axes: title={'center': 'Cost Analysis'}, xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# **to see which gender they are, we are gonna use c and not use color which will through an error.**

# %%
tips.plot(
    kind="scatter",
    x="total_bill",
    y="tip",title="Cost Analysis",
    c="sex",
    marker="*",
    figsize=(10,6),
    s=tips["size"]*20
)
# Out:
# <Axes: title={'center': 'Cost Analysis'}, xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# **using cmap, for diffeent color**

# %%
tips.plot(
    kind="scatter",
    x="total_bill",
    y="tip",title="Cost Analysis",
    c="sex",
    marker="*",
    figsize=(10,6),
    s=tips["size"]*20,
    cmap="viridis"
)
# Out:
# <Axes: title={'center': 'Cost Analysis'}, xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Line Plot

# %%
stocks = pd.read_csv('https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv')
stocks.head()
# Out:
#          Date        MSFT          FB        AAPL
# 0  2021-05-24  249.679993  328.730011  124.610001
# 1  2021-05-31  250.789993  330.350006  125.889999
# 2  2021-06-07  257.890015  331.260010  127.349998
# 3  2021-06-14  259.429993  329.660004  130.460007
# 4  2021-06-21  265.019989  341.369995  133.110001

# %%
stocks["MSFT"].plot(kind="line")
# Out:
# <Axes: >

# %%
stocks.plot(kind="line")
# Out:
# <Axes: >

# %%
stocks.plot(kind="line",x="Date")
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# **If we only want MSFT and FB not AAPL then**

# %%
stocks[["Date","MSFT","FB"]].plot(kind="line",x="Date",color=["green","red"])
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Bar Chart
# * **Single**
# * **Horizontal**
# * **Multiple**

# %%
#using tips
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
temp = tips.groupby("sex",observed=False)["total_bill"].mean()
temp
# Out:
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
temp.plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %%
#Another dataset
batsman_season_record = pd.read_csv("02/batsman_season_record.csv")
batsman_season_record
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %% [markdown]
# #### Multiple Bar Chart

# %%
batsman_season_record.plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# #### Single Bar Chart

# %% [markdown]
# **This way it gives us multiple bar chart if we just want just single like only the bar chart of 2015 the we could do this,**

# %%
batsman_season_record[["batsman","2015"]].plot(kind="bar",x="batsman",y="2015")
# Out:
# <Axes: xlabel='batsman'>

# %%
#or
batsman_season_record.plot(kind="bar",x="batsman",y="2015")
# Out:
# <Axes: xlabel='batsman'>

# %% [markdown]
# #### Horizontal
# **Just use *kind="barh"* instead of *kind="bar"***.

# %%
batsman_season_record.plot(kind="barh",x="batsman",y="2015",grid=True)
# Out:
# <Axes: ylabel='batsman'>

# %% [markdown]
# ### Stacked Bar Chart

# %% [markdown]
# **To make a stacked bar chart, all we have to do is *stacked=True***.

# %%
batsman_season_record.plot(kind="bar",stacked=True,edgecolor="black")
# Out:
# <Axes: >

# %% [markdown]
# ### Histogram

# %%
# using stocks dataset
stocks.head()
# Out:
#          Date        MSFT          FB        AAPL
# 0  2021-05-24  249.679993  328.730011  124.610001
# 1  2021-05-31  250.789993  330.350006  125.889999
# 2  2021-06-07  257.890015  331.260010  127.349998
# 3  2021-06-14  259.429993  329.660004  130.460007
# 4  2021-06-21  265.019989  341.369995  133.110001

# %%
stocks.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
stocks[["MSFT","FB"]].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Increasing bins**

# %%
stocks.plot(kind="hist",bins=40)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Pie Chart
# * **Single**
# * **Multiple**

# %%
df = pd.DataFrame(
    {
        'batsman':['Dhawan','Rohit','Kohli','SKY','Pandya','Pant'],
        'match1':[120,90,35,45,12,10],
        'match2':[0,1,123,130,34,45],
        'match3':[50,24,145,45,10,90]
    }
)

df.head()
# Out:
#   batsman  match1  match2  match3
# 0  Dhawan     120       0      50
# 1   Rohit      90       1      24
# 2   Kohli      35     123     145
# 3     SKY      45     130      45
# 4  Pandya      12      34      10

# %% [markdown]
# #### Single Pie Chart

# %% [markdown]
# ***We are needed to give here, y parameter in a dataframe else it will give error or if you want to make pie chart of every numerical column then, subplots=True.***

# %%
df.plot(kind="pie",labels=df["batsman"],y="match1",autopct="%0.2f%%")
# Out:
# <Axes: ylabel='match1'>

# %%
#or
df["match1"].plot(kind="pie",labels=df["batsman"],autopct="%0.2f%%")
# Out:
# <Axes: ylabel='match1'>

# %% [markdown]
# #### Multiple Pie Charts

# %%
df[["match1","match2","match3"]].plot(kind="pie",labels=df["batsman"],subplots=True,autopct="%0.2f%%",figsize=(14,9))
# Out:
# array([<Axes: ylabel='match1'>, <Axes: ylabel='match2'>,
#        <Axes: ylabel='match3'>], dtype=object)

# %% [markdown]
# ### Multiple Separate Graphs / Subplots

# %%
#using stocks
stocks.plot(kind="line",subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# ### On Multiindex Dataframe

# %%
#using tips
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
pd.pivot_table(tips,columns=["sex","smoker"],index=["day","time"],values="total_bill",aggfunc="mean").plot(kind="line")
# Out:
# C:\Users\AK\AppData\Local\Temp\ipykernel_12296\4099249699.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(tips,columns=["sex","smoker"],index=["day","time"],values="total_bill",aggfunc="mean").plot(kind="line")
# <Axes: xlabel='day,time'>

# %%
pd.pivot_table(tips,columns=["sex","smoker"],index=["day","time"],aggfunc="mean").plot(kind="line")
# Out:
# C:\Users\AK\AppData\Local\Temp\ipykernel_12296\1062127030.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(tips,columns=["sex","smoker"],index=["day","time"],aggfunc="mean").plot(kind="line")
# <Axes: xlabel='day,time'>

# %%
pd.pivot_table(tips,columns=["sex","smoker"],index=["day","time"],values="total_bill",aggfunc="mean").plot(kind="bar")
# Out:
# C:\Users\AK\AppData\Local\Temp\ipykernel_12296\1692103280.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(tips,columns=["sex","smoker"],index=["day","time"],values="total_bill",aggfunc="mean").plot(kind="bar")
# <Axes: xlabel='day,time'>

# %%
pd.pivot_table(tips,columns=["sex","smoker"],index=["day","time"],values="total_bill",aggfunc="mean").plot(kind="pie",subplots=True,figsize=(20,14))
# Out:
# C:\Users\AK\AppData\Local\Temp\ipykernel_12296\2314544600.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(tips,columns=["sex","smoker"],index=["day","time"],values="total_bill",aggfunc="mean").plot(kind="pie",subplots=True,figsize=(20,14))
# array([<Axes: ylabel='(Male, Yes)'>, <Axes: ylabel='(Male, No)'>,
#        <Axes: ylabel='(Female, Yes)'>, <Axes: ylabel='(Female, No)'>],
#       dtype=object)

# %% [markdown]
# ### Important Note:
# ***This pandas plot only on Series and DataFrame.***
