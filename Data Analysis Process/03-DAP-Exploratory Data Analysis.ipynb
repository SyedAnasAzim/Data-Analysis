# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Titanic Dataset Description
#
# The **Titanic dataset** is a famous dataset used in data science and machine learning for practicing **data cleaning, exploratory data analysis (EDA), and classification**. It is based on real passenger data from the RMS Titanic, which sank on April 15, 1912.
#
# ## Columns / Features
#
# 1. **PassengerId** – Unique identifier for each passenger.
# 2. **Survived** – Survival status (0 = Did not survive, 1 = Survived).
# 3. **Pclass** – Ticket class (1 = 1st class, 2 = 2nd class, 3 = 3rd class).
# 4. **Name** – Passenger’s full name (includes titles like Mr., Mrs., Miss, etc.).
# 5. **Sex** – Gender of the passenger (male/female).
# 6. **Age** – Age in years (may contain missing values).
# 7. **SibSp** – Number of siblings/spouses aboard the Titanic.
# 8. **Parch** – Number of parents/children aboard the Titanic.
# 9. **Ticket** – Ticket number (not very structured).
# 10. **Fare** – Ticket price paid.
# 11. **Cabin** – Cabin number (many missing values).
# 12. **Embarked** – Port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton).

# %%
df = pd.read_csv("03/train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Why do EDA
#
# - Model building
# - Analysis and reporting
# - Validate assumptions
# - Handling missing values
# - feature engineering
# - detecting outliers

# %% [markdown]
# ## Steps of EDA
#
# 1. **Label Columns with Their Data Types**
#    - Identify numerical, categorical, and textual columns.
#    - Check dtypes using `.info()` and correct them if needed.
#
# 2. **Univariate Analysis**
#    - Explore each column individually.
#    - Numerical features → histograms, boxplots, summary statistics.
#    - Categorical features → value counts, bar plots.
#
# 3. **Bivariate Analysis**
#    - Explore relationships between independent features and the target variable.
#    - Use grouped bar charts, boxplots, cross-tabs, scatter plots.
#
# 4. **Multivariate Analysis**
#    - Explore relationships among multiple variables at once.
#    - Use heatmaps, pair plots, stacked charts.
#
# 5. **Missing Values**
#    - Identify missing values (`.isnull().sum()`).
#    - Handle them by dropping, imputing, or creating missing indicators.
#
# 6. **Outlier Detection**
#    - Detect outliers using boxplots, z-scores, or IQR method.
#    - Decide to remove, cap, transform, or create an outlier indicator feature.
#
# 7. **Feature Engineering**
#    - Create new features or transform existing ones:
#      - Encoding categorical variables
#      - Binning continuous variables
#      - Creating interaction features
#      - Adding indicators (e.g., `is_missing`, `is_outlier`)
#      - Transforming skewed features
#
# #### *Important Note:*
# **Remember it is an iterative process.**

# %% [markdown]
# ### Data Types
#   - Numerical: `Age`, `SibSp`, `Parch`, `Fare`
#   - Categorical: `Sex`, `Pclass`, `Embarked`
#   - Textual/Unstructured: `Name`, `Ticket`, `Cabin`
#
# ### Univariate Analysis
#
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# - **Distribution analysis**: The distribution of each feature is examined to identify its shape, central tendency (mean, median ,mode), and dispersion.
#
# - **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values

# %% [markdown]
# #### The shape of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution**: A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution**: A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed). This makes mean and median diffrernt from each other.
#
# - **Bimodal Distribution**: A distribution with two peaks or modes.
#
# - **Uniform Distribution**: A distribution where all values have an equal chance of occurring.
#
# The shape of the data distribution is important in identifying the presence of outliers, skewness, and the type of statistical tests and models that can be used for further analysis.

# %% [markdown]
# ![3e342f0a-567f-4324-b716-34add31bc9ff.png](attachment:5f387edd-7730-469f-be54-12726d41ea53.png)

# %% [markdown]
# #### **Dispersion** is a statistical term used to describe the spread or variability of a set of data. It measures how far the values in a data set are spread out from the central tendency (mean, median, or mode) of the data.
#
# There are several measures of dispersion, including:
#
# - **Range**: The difference between the largest and smallest values in a data set.
#
# - **Variance**: The average of the squared deviations of each value from the mean of the data set.
#
# - **Standard Deviation**: The square root of the variance. It provides a measure of the spread of the data that is in the same units as the original data.
#
# - **Interquartile range (IQR)**: The range between the first quartile (25th percentile) and the third quartile (75th percentile) of the data.
#
# Dispersion helps to describe the spread of the data, which can help to identify the presence of outliers and skewness in the data.
#
# ---
# ---
#
# ### Univariate Analysis Conclusions:
#
# #### 1. Numerical Columns (`int`, `float`)
# - Focus: Mean, median, variance, skewness, outliers.
# - Example Conclusions:
#   - The **Age** column is right-skewed, with most values between 20–40 years. Few extreme values above 70 may be outliers.
#   - The **Fare** column has a wide range (0–500). Median is around 15, but a few very high values indicate potential outliers.
#
# ---
#
# #### 2. Categorical Columns (`object`, `category`)
# - Focus: Mode, frequency distribution, balance/imbalance, rare categories.
# - Example Conclusions:
#   - The **Gender** column is fairly balanced (55% male, 45% female).
#   - The **Embarked** column shows most passengers from port **S** (70%), while **C** and **Q** are less common.
#   - The **Genre** column has many categories, but top 3 cover about 60% of the data.
#
# ---
#
# #### 3. Boolean Columns (`True/False`, `0/1`)
# - Focus: Proportions, imbalance.
# - Example Conclusions:
#   - The **Purchased** column indicates 65% customers purchased (1), 35% did not (0).
#   - The imbalance suggests preprocessing (e.g., resampling) may be needed for modeling.
#
# ---
#
# #### 4. Datetime Columns (`datetime64`)
# - Focus: Trends, peaks, seasonality, weekday/weekend patterns.
# - Example Conclusions:
#   - The **Order Date** column shows most sales between 2018–2020, with a peak in December each year.
#   - Orders are more frequent on weekdays than weekends.
#
# ---
#
# #### 5. Text Columns (Free Text)
# - Focus: Length, word frequency, missing values.
# - Example Conclusions:
#   - The **Review** column has an average of 120 characters per entry. Common words include *“good”*, *“service”*, and *“fast”*.
#   - About 10% of reviews are missing or blank.
#
# ---

# %% [markdown]
# ### Steps of doing Univariate Analysis on Numerical columns
#
# - **Descriptive Statistics**: Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# - **Visualizations**: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# - **Identifying Outliers**: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# - **Skewness**: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# - **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# *Here, we focus on Age and Fare numerical columns because they could determine a trends unlike passengerid.*

# %% [markdown]
# #### Age
# **Conclusions:**
# - Age is normally(almost) distributed
# - 20% of the values are missing
# - There are some outliers

# %%
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df["Age"].plot(kind="hist",bins=16)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Age"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ***skew Function***
#
# The skew() function is used to calculate the skewness of a distribution, i.e., whether your data is symmetrically distributed or skewed (left or right).
# Interpretation of Skewness:
#
# * 0 → Perfectly symmetric (like normal distribution).
# * '> 0 → Positively skewed (right tail is longer).
# * < 0 → Negatively skewed (left tail is longer).
#
# **⚡ Example:**
# * If skew = 1.2, distribution is right-skewed.
# * If skew = -0.8, distribution is left-skewed.
#
# *Close to zero is also good.*

# %%
df["Age"].skew()
# Out:
# 0.38910778230082704

# %%
df["Age"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# **Maximum:**
# > The highest data point, excluding outliers, and the end of the right whisker.
#
# **Minimum:**
# > The lowest data point, excluding outliers, and the end of the left whisker.

# %%
# outliers
Q1 = 20.125000
Q3 = 38.000000
IQR = Q3-Q1 #17.875
Max = Q3+1.5*IQR #64.8125
df[df["Age"] > Max]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 280          281         0       3                      Duane, Mr. Frank
# 456          457         0       1             Millet, Mr. Francis Davis
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
# Missing values
df["Age"].isna().sum()/df["Age"].size # means one in five person has missing age
# Out:
# 0.19865319865319866

# %% [markdown]
# #### Fare
# **Conclusions:**
# - The data is highly(positively) skewed
# - Fare col actually contains the group fare and not the individual fare(This migth be and issue)
# - We need to create a new col called individual fare

# %%
df["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df["Fare"].plot(kind="hist",bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Fare"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Fare"].skew() #highly positively skewed
# Out:
# 4.787316519674893

# %%
df["Fare"].plot(kind="box") # too many outliers
# Out:
# <Axes: >

# %%
df[df["Fare"] > 250] #so, fare is not single fare but grouped fare
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
df["Fare"].isnull().sum() # no missing values
# Out:
# 0

# %% [markdown]
# ### Steps of doing Univariate Analysis on Categorical columns
#
# **Descriptive Statistics**: Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Visualizations**: Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include count plots and pie charts. These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
# **Missing Values**: Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# **Categorical columns: `Survived`,`Pclass`,`Sex`,`SibSp`,`Parch` and `Embarked`**

# %% [markdown]
# ### Survived
# **Conclusions:**
# * There are more people died than survived.
# * 61.61% people died.
# * There are no missing values.

# %%
# 0 -> died
# 1 -> Survived
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df["Survived"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Survived'>

# %%
df["Survived"].value_counts().plot(kind="pie",autopct="%0.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# Missing Values
df["Survived"].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Pclass
# **Conclusions:**
# * There are more people in Pclass 3 (55.11%) then 1 (24.24%) and 2 (20.65%).
# * Surprisingly more people travelled through 1 than 2.
# * No missing values.

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x="Pclass")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
plt.pie(x=df["Pclass"].value_counts(),labels=[3,1,2],autopct="%0.2f%%",shadow=True,colors=["green","blue","brown"])
plt.legend()
plt.show()

# %%
df["Pclass"].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Sex
# **Conclusions:**
# * There are 64.76% males and 35.24% females.
# * No missing values.

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
plt.bar(df["Sex"].value_counts().index,df["Sex"].value_counts())
plt.xlabel("Sex")
plt.xticks(rotation=90)
plt.show()

# %%
df["Sex"].value_counts().plot(kind="pie",autopct="%0.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["Sex"].isna().sum()
# Out:
# 0

# %% [markdown]
# ### SibSp
# **Conclusions:**
# * There are more people with more no siblings and spouse then there are with.
# * No missing values.

# %%
df["SibSp"].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df["SibSp"].value_counts().plot(kind="bar",grid=True)
# Out:
# <Axes: xlabel='SibSp'>

# %%
df["SibSp"].value_counts().plot(kind="pie",autopct="%0.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["SibSp"].value_counts() * 100 / df["SibSp"].size
# Out:
# SibSp
# 0    68.237935
# 1    23.456790
# 2     3.142536
# 4     2.020202
# 3     1.795735
# 8     0.785634
# 5     0.561167
# Name: count, dtype: float64

# %%
df["SibSp"].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Parch
# **Conclusions:**
# * There are more people with more no parents and children then there are with.
# * No missing values.

# %%
df["Parch"].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df["Parch"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Parch'>

# %%
df["Parch"].value_counts().plot(kind="pie",autopct="%0.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["Parch"].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Embarked
# **Conclusions:**
# * There are more people embarked from Southampton than Cherbourg and Queenstown.
# * There are 2 missing values.

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df["Embarked"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Embarked'>

# %%
df["Embarked"].value_counts().plot(kind="pie",autopct="%0.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["Embarked"].isna().sum()
# Out:
# 2

# %%
df[df["Embarked"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# ### Conclusions:
# * `SibSp` and `Parch` should be one column named `Family_size`.
# * Create a new column named `is_alone`.

# %% [markdown]
# **Mixed Columns needs to be featured engineeried into a suitable data type to do univariate analysis.**

# %% [markdown]
# ### Steps of doing Bivariate Analysis
#
# - Select 2 cols
# - Understand type of relationship
#     1. **Numerical - Numerical**<br>
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
#         b. Check correlation coefficent to check linear relationship
#     2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>
#     3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like heatmap, stacked barplots, treemaps
#
# - Write your conclusions

# %% [markdown]
# > #### Important Note:
# ***When doing bivariate analysis, don't blindly make combinations select target column or columns and then do bivariate analysis with other columns that make sense.***

# %% [markdown]
# * Here, there are two important columns, one is Survived (it's the goal) and the other is Age (contains missing values need o analyze other columns to fill its values).

# %% [markdown]
# ### Survived vs Pclass
# `Categorical - Categorical`
#
# **Conclusions:**
# * Survival chances strongly depended on passenger class.
# * 1st Class had the highest survival rate (~63%).
# * 3rd Class had the lowest survival rate (~24%).
# * 2nd Class survival rate was in between (~47%).
# * Overall, the higher the class, the better the survival chances.

# %%
pd.crosstab(df["Survived"],df["Pclass"])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %% [markdown]
# Now, normalize using a normalize parameter in crosstab,
# | Option            | Meaning                                                                                |
# | ----------------- | -------------------------------------------------------------------------------------- |
# | `False` (default) | No normalization. Counts are returned.                                                 |
# | `True` or `"all"` | Normalize over **all values** → each cell is divided by the total sum of the crosstab. |
# | `"index"`         | Normalize **row-wise** → each row sums to 1.                                           |
# | `"columns"`       | Normalize **column-wise** → each column sums to 1.                                     |

# %%
tab = pd.crosstab(df["Survived"],df["Pclass"],normalize="columns")*100 # used hundred to make it into percent
tab
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
plt.imshow(tab,cmap="inferno")
plt.colorbar()
plt.xlabel("Pclass")
plt.ylabel("Survived")
plt.xticks([0,1,2],[1,2,3])
plt.yticks([0,1])
plt.show()

# %% [markdown]
# ### Survived vs Sex
# `Categorical - Categorical`
#
# **Conclusions:**
# * Survival chances strongly depends on sex of the person.
# * 74.2% of female passengers survived.
# * only 18.9% of male passengers survived.

# %%
tab = pd.crosstab(df["Survived"],df["Sex"],normalize="columns")*100 # used hundred to make it into percent
tab
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
sns.heatmap(tab)
plt.show()

# %% [markdown]
# ### Survived vs Embarked
# `Categorical - Categorical`
#
# **Conclusions:**
# * We can see that there are significantly more people who embarked from C are in Pclass 1 than Q and S and this shows that this could be the high survival rate.

# %%
tab = pd.crosstab(df["Survived"],df["Embarked"],normalize="columns")*100 # used hundred to make it into percent
tab
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
sns.heatmap(tab)
plt.show()

# %% [markdown]
# **There are more people survived who embarked from C then Q and S. There could be two reasons for that :**
# 1. *Sex*
# 2. *Pclass*

# %%
pd.crosstab(df["Sex"],df["Embarked"],normalize="columns")*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %% [markdown]
# **From this cross-tab, percentage of sex in C and Q are similar to each other so, this can't be the reason for most survival.**

# %%
pd.crosstab(df["Pclass"],df["Embarked"],normalize="columns")*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %% [markdown]
# **Here, we can see that there are significantly more people who embarked from C are in Pclass 1 than Q and S.**

# %% [markdown]
# ### Survived vs Age
# `Categorical - Numerical`
#
# **Conclusions:**

# %%
df[df["Survived"] == 1]["Age"].plot(kind="kde",label="Survived")
df[df["Survived"] == 0]["Age"].plot(kind="kde",label="Not Survived")
plt.legend()
plt.show()

# %% [markdown]
# **This means that in graph we can see that at some point near 40 bllue one is dominating orange one is because that at that age more people are in Pclass.**

# %%
df[df["Pclass"]==1]["Age"].mean()
# Out:
# 38.233440860215055

# %% [markdown]
# > **Important Point:**
# ***If the KDE curves of two groups overlap a lot, the variable does not make much difference. If the curves are clearly separated, the variable makes a difference.***

# %% [markdown]
# ## Feature Engineering

# %%
df["Ticket"].value_counts()
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
df[df["Ticket"] == "CA. 2343"]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %% [markdown]
# ***This doesn't look complete because the dataset is divide into two parts let's import it and then do feature engineering.***

# %%
df1 = pd.read_csv("03/test.csv")

# %%
df1 = pd.concat([df,df1])

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1[df1["Ticket"] == "CA. 2343"]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 342         1234       NaN       3              Sage, Mr. John George    male
# 360         1252       NaN       3        Sage, Master. William Henry    male
# 365         1257       NaN       3     Sage, Mrs. John (Annie Bullen)  female
#
# ...

# %% [markdown]
# *As, we can see the issue is resolved, let's jump to feature engineering*

# %%
df1["Family_size"] = df1["SibSp"]+df1["Parch"]
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1["Individual_Fare"] = df1["Fare"]/(df1["Family_size"]+1)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1["Individual_Fare"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# **This mush outliers is because someone had paid that much fare.**

# %% [markdown]
# Lets make a new column `Family_type`
# * 0 -> "alone"
# * 1-3 -> "small"
# * '>3 ->"large"

# %%
def family_type_finder(num):
    if num == 0:
        return "alone"
    elif num <= 3:
        return "small"
    else:
        return "large"

# %%
df1["Family_type"] = df1["Family_size"].apply(family_type_finder)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Doing bivariate analysis on `Survived` and `Family_type` columns

# %%
pd.crosstab(df1["Survived"],df1["Family_type"],normalize="columns")*100
# Out:
# Family_type      alone      large      small
# Survived
# 0.0          69.646182  83.870968  42.123288
# 1.0          30.353818  16.129032  57.876712

# %% [markdown]
# #### We will create a new column named surname using Name column

# %%
df1["Surname"] = df1["Name"].str.split(",").str[0]

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### We will create a new column named Title using Name column

# %%
df1["Title"] = df1["Name"].str.split(",").str[1].str.strip().str.split().str.get(0)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1["Title"].value_counts()
# Out:
# Title
# Mr.          757
# Miss.        260
# Mrs.         197
# Master.       61
# Rev.           8
# Dr.            8
# Col.           4
# Mlle.          2
# Major.         2
# Ms.            2
# Lady.          1
# Sir.           1
# Mme.           1
# Don.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Dona.          1
# Name: count, dtype: int64

# %%
df1["Title"].replace({
    "Rev.":"Others",
    "Dr.":"Others",
    "Col.":"Others",
    "Major.":"Others",
    "Sir.":"Others",
    "Don.":"Others",
    "Capt.":"Others",
    "Jonkheer.":"Others",
    "the":"Others"
}).value_counts()
# Out:
# Title
# Mr.        757
# Miss.      260
# Mrs.       197
# Master.     61
# Others      27
# Ms.          2
# Mlle.        2
# Mme.         1
# Lady.        1
# Dona.        1
# Name: count, dtype: int64

# %%
temp_df = df1[df1["Title"].isin(["Ms.","Mr.","Miss.","Mrs.","Master.","Others"])]

# %%
pd.crosstab(temp_df["Survived"],temp_df["Title"],normalize="columns")*100
# Out:
# Title     Master.     Miss.        Mr.  Mrs.    Ms.
# Survived
# 0.0          42.5  30.21978  84.332689  20.8    0.0
# 1.0          57.5  69.78022  15.667311  79.2  100.0

# %%
df1["Cabin"].isna().sum()/len(df1["Cabin"])
# Out:
# 0.774637127578304

# %%
df1["Cabin"].value_counts().head(20)
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# C22 C26            4
# F33                4
# F2                 4
# B96 B98            4
# C78                4
# F4                 4
# D                  4
# E34                3
# B58 B60            3
# A34                3
# E101               3
# C101               3
# B51 B53 B55        3
# C31                2
# C55 C57            2
# D37                2
# C54                2
# Name: count, dtype: int64

# %%
df1["Cabin"].fillna("M",inplace=True)

# %%
df1["Deck"] = df1["Cabin"].str.strip().str.get(0)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1["Deck"].value_counts()
# Out:
# Deck
# M    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: count, dtype: int64

# %%
pd.crosstab(df1["Deck"],df1["Pclass"])
# Out:
# Pclass   1    2    3
# Deck
# A       22    0    0
# B       65    0    0
# C       94    0    0
# D       40    6    0
# E       34    4    3
# F        0   13    8
# G        0    0    5
# M       67  254  693
# T        1    0    0

# %%
pd.crosstab(df1["Deck"],df1["Survived"],normalize="index").plot(kind="barh",stacked=True,grid=True)
# Out:
# <Axes: ylabel='Deck'>

# %%
df1.corr(numeric_only=True)
# Out:
#                  PassengerId  Survived    Pclass       Age     SibSp  \
# PassengerId         1.000000 -0.005007 -0.038354  0.028814 -0.055224
# Survived           -0.005007  1.000000 -0.338481 -0.077221 -0.035322
# Pclass             -0.038354 -0.338481  1.000000 -0.408106  0.060832
# Age                 0.028814 -0.077221 -0.408106  1.000000 -0.243699
# SibSp              -0.055224 -0.035322  0.060832 -0.243699  1.000000
# Parch               0.008942  0.081629  0.018322 -0.150917  0.373587
# Fare                0.031428  0.257307 -0.558629  0.178740  0.160238
# Family_size        -0.031437  0.016639  0.050027 -0.240229  0.861952
# Individual_Fare     0.035365  0.221600 -0.504270  0.193545 -0.089807
#
#                     Parch      Fare  Family_size  Individual_Fare
# PassengerId      0.008942  0.031428    -0.031437         0.035365
# Survived         0.081629  0.257307     0.016639         0.221600
# Pclass           0.018322 -0.558629     0.050027        -0.504270
# ...

# %%
df1.corr(numeric_only=True)["Survived"]
# Out:
# PassengerId       -0.005007
# Survived           1.000000
# Pclass            -0.338481
# Age               -0.077221
# SibSp             -0.035322
# Parch              0.081629
# Fare               0.257307
# Family_size        0.016639
# Individual_Fare    0.221600
# Name: Survived, dtype: float64

# %%
sns.heatmap(df1.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.pairplot(df)
